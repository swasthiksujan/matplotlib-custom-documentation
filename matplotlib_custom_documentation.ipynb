# %% [markdown]
# # `matplotlib` - A Custom Documentation
# ---
#
# Getting started with `matplotlib`

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

array = np.arange(1, 101).reshape([50, 2])

df = pd.DataFrame(array)

x_axis = df.iloc[:, 0]
y_axis = df.iloc[:, 1]

array2 = np.arange(-100, 0).reshape([50, 2])
df2 = pd.DataFrame(array2)

x_axis2 = df.iloc[:, 0]
y_axis2 = df.iloc[:, 1]

plot = plt.plot(df, df2)
